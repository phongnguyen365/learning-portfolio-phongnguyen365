# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Storing Data (Good) Exercises</span></div>

# %% [markdown]
# **Exercise 1**

# %% [markdown]
# | **Term** | **Brief description** |
# |:---:|:---:|
# | Subsetting | select a number of elements (min. 1) |
# | Indexing | Select an element |
# | Slicing | Select a range of elements |
# | Masking | Select a number of elements that fulfill a (or some) condition(s) |

# %% [markdown]
# **Exercise 2**

# %%
import numpy as np
np_array_2d = np.array([[1, "A"], [3, "C"], [2, "B"], [4, "D"],
                        [5, "E"], [7, "G"], [6, "F"], [8, "H"],
                        [10, "J"], [9, "I"]])
np_array_1d = np_array_2d[:,0]
np_array_1d = np_array_1d.astype(int)
np_array_odd = np_array_2d[np_array_1d % 2 != 0]
np_array_odd[:,1]
# Out:
# array(['A', 'C', 'E', 'G', 'I'], dtype='<U11')
